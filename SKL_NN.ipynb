# %% [markdown]
# ### This notebook implements :
# 1. Perceptron fitting on data of 4 component task.
# 2. Investigation of NN weights distribution after fitting.
# 3. Varying 1 NN weight and viewing Error value dependence.
# 4. Realisation Weights2Chrom() and Chrom2Weights() for GA.
#
# ---
# Functions, that are used in this notebook, are written in moduls:
# * raw_data_processing.py
# * nn_weights_stats.py
# * nn_vary_weights.py
# * phen_gen_transform.py

# %%
import os
import sys
import numpy as np
import pandas as pd
from copy import deepcopy

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

import torch
from kan import KAN

# %%
from raw_data_processing import get_x, get_y
from json_tools import JSON_Read

# %%
SCRIPT_DIR = os.path.abspath('')

# %% [markdown]
# ## Loading data

# %%
d_config = JSON_Read("", "json_config.txt")
#locals().update(d_config)  # Transfer dict data to variables
d_config
# Out:
# {'SPEC_FOLDER': 'full_data',
#  'EXCITE_WAVE_LENGTH': 350,
#  'PREDICT_IONS': ['Cr'],
#  'TRAIN_TEST_RATIO': 0.9,
#  'VALIDATION_TRAIN_RATIO': 0.2857,
#  'RANDOM_STATE_SPLIT': 42,
#  'N_ITER_NO_CHANGE': 100,
#  'HIDDEN_LAYER_SIZES': 500,
#  'RANDOM_STATE_TRAIN': 42,
#  'ACTIVATION': 'tanh',
#  'SOLVER': 'adam',
#  'EARLY_STOPPING': True,
#  'MAX_ITER': 1000}

# %%
EXCITE_WAVE_LENGTH = d_config['EXCITE_WAVE_LENGTH']
PREDICT_IONS = d_config['PREDICT_IONS']
SPEC_FOLDER = d_config['SPEC_FOLDER']

TRAIN_TEST_RATIO = d_config['TRAIN_TEST_RATIO']
VALIDATION_TRAIN_RATIO = d_config['VALIDATION_TRAIN_RATIO']
N_ITER_NO_CHANGE = d_config['N_ITER_NO_CHANGE']

HIDDEN_LAYER_SIZES = d_config['HIDDEN_LAYER_SIZES']
ACTIVATION = d_config['ACTIVATION']
SOLVER = d_config['SOLVER']

# %%
x = get_x(wave_length=EXCITE_WAVE_LENGTH, spec_file=""+SPEC_FOLDER)
y = get_y(l_ions=PREDICT_IONS, spec_file=""+SPEC_FOLDER)

# %%
x
# Out:
#        250.0   255.0   260.0   265.0   270.0   275.0   280.0   285.0   290.0  \
# 350.0   4.15   5.212    2.08   5.058   4.813   6.879   8.172   7.779   10.09
# 350.0  7.943  12.713  12.463  14.929  11.239  13.068  13.382  14.356  16.383
# 350.0  6.549   4.952   9.749   8.882    9.75  10.652  10.188  12.526  12.429
# 350.0  6.338   9.674   7.187   7.756   9.899   9.791  11.961  11.529  11.564
# 350.0  7.713  10.974  10.424   9.317   9.092   7.543   9.271  10.471  12.057
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 350.0  5.527   7.413   8.765    5.82   7.059   6.475   7.843   8.311   8.545
# 350.0  7.796   6.023   6.897     8.4   7.555   8.281   9.614   7.984   9.672
# 350.0  2.968   8.047   8.038   7.762   8.218   7.456   8.039   8.615   8.495
# 350.0  3.935   7.241   9.459   9.109   7.312     9.2   9.163   8.627   8.234
# 350.0   8.18   7.893   8.176    8.25    8.01   8.534   8.898   7.742   8.503
#
#         295.0  ...  405.0  410.0  415.0  420.0  425.0  430.0  435.0  440.0  \
# 350.0  11.061  ...  0.347   0.26   0.32  0.299  0.314  0.303   0.37  0.401
# 350.0  15.328  ...  0.884  0.907   0.74  0.848  0.699  0.879  0.694  0.625
# 350.0  11.653  ...  0.282  0.377  0.276  0.337  0.491  0.493  0.299  0.405
# 350.0  13.391  ...  0.305  0.456  0.284  0.263  0.381  0.401   0.32  0.299
# 350.0  10.467  ...  0.387  0.388  0.193  0.269  0.318  0.364  0.387  0.297
# ...       ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 350.0   6.982  ...  0.531  0.514  0.381  0.536    0.5  0.592  0.541  0.435
# 350.0   8.594  ...  0.642  0.522  0.337  0.548  0.555  0.694  0.475  0.572
# 350.0   6.876  ...   0.39  0.479  0.494  0.398  0.419  0.529  0.609   0.57
# 350.0   8.154  ...  0.448  0.655  0.416  0.411  0.371  0.532   0.33  0.396
# 350.0   7.984  ...  0.539  0.576  0.462  0.298   0.37  0.274  0.426  0.444
#
#        445.0  450.0
# 350.0   0.23  0.302
# 350.0   0.59  0.491
# 350.0  0.302   0.43
# 350.0  0.387  0.353
# 350.0    0.3  0.317
# ...      ...    ...
# 350.0  0.446  0.352
# 350.0  0.569  0.505
# 350.0  0.588  0.417
# 350.0   0.53  0.363
# 350.0  0.371  0.385
#
# [1000 rows x 41 columns]

# %%
y
# Out:
# array([0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  ,
#        0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55,
#        1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 ,
#        1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65,
#        2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 ,
#        2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75,
#        3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 ,
#        3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85,
#        4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 ,
#        4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95,
#        0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  ,
#        0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55,
#        1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 ,
#        1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65,
#        2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 ,
#        2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75,
#        3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 ,
#        3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85,
#        4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 ,
#        4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95,
#        0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  ,
#        0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55,
#        1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 ,
#        1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65,
#        2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 ,
#        2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75,
#        3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 ,
#        3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85,
#        4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 ,
#        4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95,
#        0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  ,
#        0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55,
#        1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 ,
#        1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65,
#        2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 ,
#        2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75,
#        3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 ,
#        3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85,
#        4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 ,
#        4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95,
#        0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  ,
#        0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55,
#        1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 ,
#        1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65,
#        2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 ,
#        2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75,
#        3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 ,
#        3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85,
#        4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 ,
#        4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95,
#        0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  ,
#        0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55,
#        1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 ,
#        1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65,
#        2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 ,
#        2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75,
#        3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 ,
#        3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85,
#        4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 ,
#        4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95,
#        0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  ,
#        0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55,
#        1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 ,
#        1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65,
#        2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 ,
#        2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75,
#        3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 ,
#        3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85,
#        4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 ,
#        4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95,
#        0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  ,
#        0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55,
#        1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 ,
#        1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65,
#        2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 ,
#        2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75,
#        3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 ,
#        3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85,
#        4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 ,
#        4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95,
#        0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  ,
#        0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55,
#        1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 ,
#        1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65,
#        2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 ,
#        2.75, 3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75,
#        3.3 , 3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 ,
#        3.85, 4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85,
#        4.4 , 4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 ,
#        4.95, 0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95,
#        0.  , 0.55, 1.1 , 1.65, 2.2 , 2.75, 3.3 , 3.85, 4.4 , 4.95])

# %% [markdown]
# ## Scaling data
# Train / Validation / Test = 0.7 / 0.2 / 0.1
#
# TRAIN_TEST_RATIO = (Train+Validation) / (Train+Validation+Test)
#
# VALIDATION_TRAIN_RATIO = Validation / Train

# %%
RS = None

x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    train_size=TRAIN_TEST_RATIO,
                                                    random_state=RS)

# %%
x_train.shape, x_test.shape
# Out:
# ((900, 41), (100, 41))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ## Model - MLP

# %%
model = MLPRegressor(hidden_layer_sizes=HIDDEN_LAYER_SIZES,
                     activation=ACTIVATION,
                     solver=SOLVER,
                     early_stopping=True,
                     validation_fraction=VALIDATION_TRAIN_RATIO,
                     n_iter_no_change=N_ITER_NO_CHANGE, 
                     learning_rate='adaptive')

# %%
# Обучение модели на тренировочных данных
model.fit(x_train, y_train)
# Out:
# MLPRegressor(activation='tanh', early_stopping=True, hidden_layer_sizes=500,
#              learning_rate='adaptive', n_iter_no_change=100,
#              validation_fraction=0.2857)

# %%
def scatter_prediction(model, 
                       x, 
                       y_true, 
                       title = ""):
    """Evaluates MSE and R^2 of model. 
    Draws scatter plot of (y_true, y_predicted).
    Returns  (mse, r2)
    """
    y_pred = model.predict(x)
    mse = mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    fig, ax = plt.subplots(figsize=(5,5))
    plt.plot(y_true, y_pred, 'o', markersize=2, alpha = 0.2) 
    plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], markersize=2, alpha = 0.5, color='r') 
    ax.set_title(f"MSE={round(mse, 5)} | R2={round(r2, 5)} | {title}")
    ax.set_xlabel("y_true")
    ax.set_ylabel("y_pred")
    plt.show()
    
    return mse, r2

# %%
scatter_prediction(model, x_train, y_train, "Train data")
scatter_prediction(model, x_test, y_test, "Test data")
# Out:
# (1.7463618091893016, 0.23606980324701432)

# %% [markdown]
# ## GridSearch for mlp Adam

# %%
parameters = {'alpha': [0, 0.001],
              #'learning_rate': ('constant', 'invscaling', 'adaptive'),
              'learning_rate_init': [0.0001, 0.01],
              'beta_1': [0.8, 0.99],
              'beta_2': [0.99, 1],
              }
model_gs = RandomizedSearchCV(model, parameters, verbose=3) #GridSearchCV
model_gs
# Out:
# RandomizedSearchCV(estimator=MLPRegressor(activation='tanh',
#                                           early_stopping=True,
#                                           hidden_layer_sizes=500,
#                                           learning_rate='adaptive',
#                                           n_iter_no_change=100,
#                                           validation_fraction=0.2857),
#                    param_distributions={'alpha': [0, 0.001],
#                                         'beta_1': [0.8, 0.99],
#                                         'beta_2': [0.99, 1],
#                                         'learning_rate_init': [0.0001, 0.01]},
#                    verbose=3)

# %%
model_gs.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END alpha=0, beta_1=0.8, beta_2=1, learning_rate_init=0.0001;, score=nan total time=   0.0s
# [CV 2/5] END alpha=0, beta_1=0.8, beta_2=1, learning_rate_init=0.0001;, score=nan total time=   0.0s
# [CV 3/5] END alpha=0, beta_1=0.8, beta_2=1, learning_rate_init=0.0001;, score=nan total time=   0.0s
# [CV 4/5] END alpha=0, beta_1=0.8, beta_2=1, learning_rate_init=0.0001;, score=nan total time=   0.0s
# [CV 5/5] END alpha=0, beta_1=0.8, beta_2=1, learning_rate_init=0.0001;, score=nan total time=   0.0s
# [CV 1/5] END alpha=0.001, beta_1=0.99, beta_2=0.99, learning_rate_init=0.01;, score=0.219 total time=   1.0s
# [CV 2/5] END alpha=0.001, beta_1=0.99, beta_2=0.99, learning_rate_init=0.01;, score=0.306 total time=   0.9s
# [CV 3/5] END alpha=0.001, beta_1=0.99, beta_2=0.99, learning_rate_init=0.01;, score=0.132 total time=   1.0s
# [CV 4/5] END alpha=0.001, beta_1=0.99, beta_2=0.99, learning_rate_init=0.01;, score=0.222 total time=   0.8s
# [CV 5/5] END alpha=0.001, beta_1=0.99, beta_2=0.99, learning_rate_init=0.01;, score=0.212 total time=   0.8s
# [CV 1/5] END alpha=0, beta_1=0.99, beta_2=0.99, learning_rate_init=0.01;, score=0.209 total time=   0.8s
# [CV 2/5] END alpha=0, beta_1=0.99, beta_2=0.99, learning_rate_init=0.01;, score=0.392 total time=   0.8s
# [CV 3/5] END alpha=0, beta_1=0.99, beta_2=0.99, learning_rate_init=0.01;, score=0.112 total time=   1.0s
# [CV 4/5] END alpha=0, beta_1=0.99, beta_2=0.99, learning_rate_init=0.01;, score=0.236 total time=   0.9s
# [CV 5/5] END alpha=0, beta_1=0.99, beta_2=0.99, learning_rate_init=0.01;, score=0.249 total time=   0.8s
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 1/5] END alpha=0, beta_1=0.99, beta_2=0.99, learning_rate_init=0.0001;, score=0.251 total time=   1.3s
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 2/5] END alpha=0, beta_1=0.99, beta_2=0.99, learning_rate_init=0.0001;, score=0.327 total time=   1.3s
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 3/5] END alpha=0, beta_1=0.99, beta_2=0.99, learning_rate_init=0.0001;, score=0.166 total time=   1.3s
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 4/5] END alpha=0, beta_1=0.99, beta_2=0.99, learning_rate_init=0.0001;, score=0.268 total time=   1.4s
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 5/5] END alpha=0, beta_1=0.99, beta_2=0.99, learning_rate_init=0.0001;, score=0.235 total time=   1.4s
# [CV 1/5] END alpha=0.001, beta_1=0.8, beta_2=0.99, learning_rate_init=0.01;, score=0.188 total time=   0.9s
# [CV 2/5] END alpha=0.001, beta_1=0.8, beta_2=0.99, learning_rate_init=0.01;, score=0.307 total time=   0.8s
# [CV 3/5] END alpha=0.001, beta_1=0.8, beta_2=0.99, learning_rate_init=0.01;, score=0.203 total time=   0.7s
# [CV 4/5] END alpha=0.001, beta_1=0.8, beta_2=0.99, learning_rate_init=0.01;, score=0.196 total time=   0.8s
# [CV 5/5] END alpha=0.001, beta_1=0.8, beta_2=0.99, learning_rate_init=0.01;, score=0.255 total time=   0.8s
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 1/5] END alpha=0, beta_1=0.8, beta_2=0.99, learning_rate_init=0.0001;, score=0.248 total time=   1.4s
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 2/5] END alpha=0, beta_1=0.8, beta_2=0.99, learning_rate_init=0.0001;, score=0.314 total time=   1.5s
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 3/5] END alpha=0, beta_1=0.8, beta_2=0.99, learning_rate_init=0.0001;, score=0.161 total time=   1.4s
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 4/5] END alpha=0, beta_1=0.8, beta_2=0.99, learning_rate_init=0.0001;, score=0.197 total time=   1.5s
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 5/5] END alpha=0, beta_1=0.8, beta_2=0.99, learning_rate_init=0.0001;, score=0.193 total time=   1.4s
# [CV 1/5] END alpha=0, beta_1=0.99, beta_2=1, learning_rate_init=0.01;, score=nan total time=   0.0s
# [CV 2/5] END alpha=0, beta_1=0.99, beta_2=1, learning_rate_init=0.01;, score=nan total time=   0.0s
# [CV 3/5] END alpha=0, beta_1=0.99, beta_2=1, learning_rate_init=0.01;, score=nan total time=   0.0s
# [CV 4/5] END alpha=0, beta_1=0.99, beta_2=1, learning_rate_init=0.01;, score=nan total time=   0.0s
# [CV 5/5] END alpha=0, beta_1=0.99, beta_2=1, learning_rate_init=0.01;, score=nan total time=   0.0s
# [CV 1/5] END alpha=0, beta_1=0.99, beta_2=1, learning_rate_init=0.0001;, score=nan total time=   0.0s
# [CV 2/5] END alpha=0, beta_1=0.99, beta_2=1, learning_rate_init=0.0001;, score=nan total time=   0.0s
# [CV 3/5] END alpha=0, beta_1=0.99, beta_2=1, learning_rate_init=0.0001;, score=nan total time=   0.0s
# [CV 4/5] END alpha=0, beta_1=0.99, beta_2=1, learning_rate_init=0.0001;, score=nan total time=   0.0s
# [CV 5/5] END alpha=0, beta_1=0.99, beta_2=1, learning_rate_init=0.0001;, score=nan total time=   0.0s
# [CV 1/5] END alpha=0, beta_1=0.8, beta_2=0.99, learning_rate_init=0.01;, score=0.261 total time=   0.8s
# [CV 2/5] END alpha=0, beta_1=0.8, beta_2=0.99, learning_rate_init=0.01;, score=0.342 total time=   0.8s
# [CV 3/5] END alpha=0, beta_1=0.8, beta_2=0.99, learning_rate_init=0.01;, score=0.171 total time=   0.8s
# [CV 4/5] END alpha=0, beta_1=0.8, beta_2=0.99, learning_rate_init=0.01;, score=0.203 total time=   0.8s
# [CV 5/5] END alpha=0, beta_1=0.8, beta_2=0.99, learning_rate_init=0.01;, score=0.208 total time=   0.7s
# [CV 1/5] END alpha=0.001, beta_1=0.8, beta_2=1, learning_rate_init=0.01;, score=nan total time=   0.0s
# [CV 2/5] END alpha=0.001, beta_1=0.8, beta_2=1, learning_rate_init=0.01;, score=nan total time=   0.0s
# [CV 3/5] END alpha=0.001, beta_1=0.8, beta_2=1, learning_rate_init=0.01;, score=nan total time=   0.0s
# [CV 4/5] END alpha=0.001, beta_1=0.8, beta_2=1, learning_rate_init=0.01;, score=nan total time=   0.0s
# [CV 5/5] END alpha=0.001, beta_1=0.8, beta_2=1, learning_rate_init=0.01;, score=nan total time=   0.0s
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 20 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'beta_2' parameter of MLPRegressor must be a float in the range [0.0, 1.0). Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\model_selection\_search.py:1052: UserWarning: One or more of the test scores are non-finite: [       nan 0.21816781 0.23975049 0.24944055 0.22997956 0.22267509
#         nan        nan 0.23705357        nan]
#   warnings.warn(
# c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# RandomizedSearchCV(estimator=MLPRegressor(activation='tanh',
#                                           early_stopping=True,
#                                           hidden_layer_sizes=500,
#                                           learning_rate='adaptive',
#                                           n_iter_no_change=100,
#                                           validation_fraction=0.2857),
#                    param_distributions={'alpha': [0, 0.001],
#                                         'beta_1': [0.8, 0.99],
#                                         'beta_2': [0.99, 1],
#                                         'learning_rate_init': [0.0001, 0.01]},
#                    verbose=3)

# %%
model_gs.best_estimator_, model_gs.best_params_, model_gs.best_score_
# Out:
# (MLPRegressor(activation='tanh', alpha=0, beta_1=0.99, beta_2=0.99,
#               early_stopping=True, hidden_layer_sizes=500,
#               learning_rate='adaptive', learning_rate_init=0.0001,
#               n_iter_no_change=100, validation_fraction=0.2857),
#  {'learning_rate_init': 0.0001, 'beta_2': 0.99, 'beta_1': 0.99, 'alpha': 0},
#  0.24944055368599533)

# %% [markdown]
# ## KAN

# %%
RS = None

x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    train_size=TRAIN_TEST_RATIO,
                                                    random_state=RS)
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

tc_x_train = torch.from_numpy(x_train)
tc_y_train = torch.from_numpy(y_train.reshape([-1,1]))
tc_x_test = torch.from_numpy(x_test)
tc_y_test = torch.from_numpy(y_test).reshape([-1,1])

dataset = {'train_input': tc_x_train,
           'train_label': tc_y_train,
           'test_input': tc_x_test,
           'test_label': tc_y_test}

# %%
tc_x_train.double()
# Out:
# tensor([[-9.9522e-01,  1.4156e+00,  6.8950e-01,  ..., -1.4325e+00,
#          -5.4759e-01,  8.8661e-01],
#         [-2.9933e-01, -1.0985e+00,  1.2313e+00,  ..., -4.5042e-02,
#           3.9436e-01,  1.0344e-01],
#         [-1.9800e-03,  1.8184e-01, -4.2344e-01,  ..., -2.9044e-01,
#          -5.5665e-01,  1.6494e+00],
#         ...,
#         [ 9.9539e-01,  1.3049e+00,  2.8389e+00,  ..., -1.0077e+00,
#           1.7077e+00,  4.4925e-01],
#         [-2.0762e+00, -1.6642e+00, -1.8293e+00,  ..., -2.1309e+00,
#          -1.3356e+00, -8.5264e-01],
#         [-8.4138e-01, -6.9989e-01, -8.7874e-01,  ...,  6.6283e-01,
#          -1.4986e+00, -1.8291e+00]], dtype=torch.float64)

# %%
# Some constants
K = 3 # order of piecewise polynomial in B-splines
INPUT_SHAPE = tc_x_test.shape[1]

# %% [markdown]
# ## Grid = 5 | hidden neurons = 5

# %%
model = KAN(width=[INPUT_SHAPE, 5, 1], grid=5, k=K)

# %%
model(dataset['train_input'])
model.plot(beta=100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\PIL\ImageFile.py:536, in _save(im, fp, tile, bufsize)
#     535 try:
# --> 536     fh = fp.fileno()
#     537     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 model(dataset['train_input'])
# ----> 2 model.plot(beta=100)
#
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\kan\KAN.py:653, in KAN.plot(self, folder, beta, mask, mode, scale, tick, sample, in_vars, out_vars, title)
#     650                 newax.imshow(im)
#     651                 newax.axis('off')
# --> 653             plt.savefig(f'{folder}/sp_{l}_{i}_{j}.png', bbox_inches="tight", dpi=400)
#     654             plt.close()
#     656 def score2alpha(score):
#
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\matplotlib\pyplot.py:1223, in savefig(*args, **kwargs)
#    1220 fig = gcf()
#    1221 # savefig default implementation has no return, so mypy is unhappy
#    1222 # presumably this is here because subclasses can return?
# -> 1223 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1224 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1225 return res
#
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\matplotlib\figure.py:3388, in Figure.savefig(self, fname, transparent, **kwargs)
#    3386     for ax in self.axes:
#    3387         _recursively_make_axes_transparent(stack, ax)
# -> 3388 self.canvas.print_figure(fname, **kwargs)
#
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\matplotlib\backend_bases.py:2218, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2214 try:
#    2215     # _get_renderer may change the figure dpi (as vector formats
#    2216     # force the figure dpi to 72), so we need to set it again here.
#    2217     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2218         result = print_method(
#    2219             filename,
#    2220             facecolor=facecolor,
#    2221             edgecolor=edgecolor,
#    2222             orientation=orientation,
#    2223             bbox_inches_restore=_bbox_inches_restore,
#    2224             **kwargs)
#    2225 finally:
#    2226     if bbox_inches and restore_bbox:
#
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\matplotlib\backend_bases.py:2068, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2064     optional_kws = {  # Passed by print_figure for other renderers.
#    2065         "dpi", "facecolor", "edgecolor", "orientation",
#    2066         "bbox_inches_restore"}
#    2067     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2068     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2069         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2070 else:  # Let third-parties do as they see fit.
#    2071     print_method = meth
#
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\matplotlib\backends\backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\matplotlib\backends\backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 """
#     441 Draw the canvas, then save it using `.image.imsave` (to which
#     442 *pil_kwargs* and *metadata* are forwarded).
#     443 """
#     444 FigureCanvasAgg.draw(self)
# --> 445 mpl.image.imsave(
#     446     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\matplotlib\image.py:1676, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1674 pil_kwargs.setdefault("format", format)
#    1675 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1676 image.save(fname, **pil_kwargs)
#
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\PIL\Image.py:2459, in Image.save(self, fp, format, **params)
#    2456         fp = builtins.open(filename, "w+b")
#    2458 try:
# -> 2459     save_handler(self, fp, filename)
#    2460 except Exception:
#    2461     if open_fp:
#
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\PIL\PngImagePlugin.py:1412, in _save(im, fp, filename, chunk, save_all)
#    1408     im = _write_multiple_frames(
#    1409         im, fp, chunk, rawmode, default_image, append_images
#    1410     )
#    1411 if im:
# -> 1412     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1414 if info:
#    1415     for info_chunk in info.chunks:
#
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\PIL\ImageFile.py:540, in _save(im, fp, tile, bufsize)
#     538     _encode_tile(im, fp, tile, bufsize, fh)
#     539 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 540     _encode_tile(im, fp, tile, bufsize, None, exc)
#     541 if hasattr(fp, "flush"):
#     542     fp.flush()
#
# File c:\Users\Gavriil\VS_projects\KAN_spectroscopy\.venv\lib\site-packages\PIL\ImageFile.py:559, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     556 if exc:
#     557     # compress to Python file-compatible object
#     558     while True:
# --> 559         errcode, data = encoder.encode(bufsize)[1:]
#     560         fp.write(data)
#     561         if errcode:
#
# KeyboardInterrupt:

# %%
result = model.train(dataset, opt="LBFGS", steps=50)
# Out:
# train loss: 2.29e-01 | test loss: 5.70e+00 | reg: 2.99e+01 : 100%|██| 50/50 [03:26<00:00,  4.12s/it]

# %%
plt.plot(result['train_loss'])
plt.plot(result['test_loss'])
plt.legend(['train', 'test'])
plt.ylabel('RMSE')
plt.xlabel('step')
# Out:
# Text(0.5, 0, 'step')

# %% [markdown]
# ## Grid=10 | hidden neurons = 5

# %%
model = KAN(width=[INPUT_SHAPE, 5, 1], grid=10, k=K, seed=None)

result = model.train(dataset, opt="LBFGS", steps=50)
# Out:
# description:   0%|                                                           | 0/50 [00:00<?, ?it/s]
# train loss: 3.65e-01 | test loss: 1.86e+00 | reg: 2.45e+01 : 100%|██| 50/50 [04:07<00:00,  4.95s/it]

# %%
plt.plot(result['train_loss'])
plt.plot(result['test_loss'])
plt.legend(['train', 'test'])
plt.ylabel('RMSE')
plt.xlabel('step')
#plt.yscale('log')
# Out:
# Text(0.5, 0, 'step')

# %% [markdown]
# ### Gradially increasing grid

# %%
width = [INPUT_SHAPE, 5, 1]
grids = np.array([3, 5, 8, 12])

train_losses = []
test_losses = []
steps = 50

for i in range(grids.shape[0]):
    if i == 0:
        model = KAN(width=width, grid=grids[i], k=K)
    if i != 0:
        model = KAN(width=width, grid=grids[i], k=K).initialize_from_another_model(model, dataset['train_input'])
    results = model.train(dataset, opt="LBFGS", steps=steps, stop_grid_update_step=30)
    train_losses += results['train_loss']
    test_losses += results['test_loss']
# Out:
# train loss: 4.57e-01 | test loss: 9.25e+00 | reg: 3.79e+01 : 100%|██| 50/50 [03:24<00:00,  4.10s/it]
# train loss: 1.89e-01 | test loss: 1.43e+01 | reg: 4.09e+01 : 100%|██| 50/50 [03:30<00:00,  4.20s/it]
# train loss: 1.47e-01 | test loss: 3.57e+04 | reg: 4.09e+01 : 100%|██| 50/50 [03:57<00:00,  4.75s/it]
# train loss: 1.36e-03 | test loss: 4.35e+02 | reg: 4.03e+01 : 100%|██| 50/50 [04:16<00:00,  5.12s/it]

# %%
plt.plot(train_losses)
plt.plot(test_losses)
plt.legend(['train', 'test'])
plt.ylabel('RMSE')
plt.xlabel('step')
plt.yscale('log')

# %% [markdown]
# ## Grid=10 | hidden neurons = 20

# %%
model = KAN(width=[INPUT_SHAPE, 20, 1], grid=10, k=K, seed=0)

result = model.train(dataset, opt="LBFGS", steps=7, lamb=0.01, lamb_entropy=10.)
# Out:
# train loss: 1.09e+00 | test loss: 2.28e+00 | reg: 1.22e+02 : 100%|████| 7/7 [02:02<00:00, 17.47s/it]

# %%
plt.plot(result['train_loss'])
plt.plot(result['test_loss'])
plt.legend(['train', 'test'])
plt.ylabel('RMSE')
plt.xlabel('step')
#plt.yscale('log')
# Out:
# Text(0.5, 0, 'step')

# %%
model.plot(beta=3)

# %%
model2 = model.prune()
model2(dataset['train_input'])
model2.plot()

# %%
result2 = model2.train(dataset, opt="LBFGS", steps=5, lamb=0.01, lamb_entropy=10.)
# Out:
# train loss: 7.42e-02 | test loss: 1.85e+00 | reg: 9.85e+01 : 100%|████| 5/5 [00:52<00:00, 10.59s/it]

# %%
plt.plot(result['train_loss'])
plt.plot(result['test_loss'])
plt.legend(['train', 'test'])
plt.ylabel('RMSE')
plt.xlabel('step')
#plt.yscale('log')

# %% [markdown]
# ### Gradially increasing grid

# %%
width = [INPUT_SHAPE, 20, 1]
grids = np.array([3, 5, 8, 12])

train_losses = []
test_losses = []
steps = 10

for i in range(grids.shape[0]):
    if i == 0:
        model = KAN(width=width, grid=grids[i], k=K)
    if i != 0:
        model = KAN(width=width, grid=grids[i], k=K).initialize_from_another_model(model, dataset['train_input'])
    results = model.train(dataset, opt="LBFGS", steps=steps, 
                          update_grid = True, 
                          grid_update_num=6,
                          stop_grid_update_step=6)
    train_losses += results['train_loss']
    test_losses += results['test_loss']
# Out:
# description:   0%|                                                           | 0/10 [00:00<?, ?it/s]
# train loss: 6.54e-01 | test loss: 2.20e+00 | reg: 4.34e+01 : 100%|██| 10/10 [02:19<00:00, 13.93s/it]
# train loss: 6.82e-01 | test loss: 6.69e+03 | reg: 4.30e+01 : 100%|██| 10/10 [02:33<00:00, 15.37s/it]
# train loss: 5.54e-01 | test loss: 5.83e+02 | reg: 4.33e+01 : 100%|██| 10/10 [02:58<00:00, 17.89s/it]
# train loss: 5.50e-01 | test loss: 5.92e+03 | reg: 4.33e+01 : 100%|██| 10/10 [01:17<00:00,  7.79s/it]

# %%
plt.plot(train_losses)
plt.plot(test_losses)
plt.legend(['train', 'test'])
plt.ylabel('RMSE')
plt.xlabel('step')
plt.yscale('log')

# %% [markdown]
# ## Grid=10 | hidden neurons = 15

# %%
model = KAN(width=[INPUT_SHAPE, 15, 1], grid=10, k=K, seed=0)

result = model.train(dataset, opt='Adam', steps=50)
# Out:
# train loss: 1.78e+01 | test loss: 1.88e+01 | reg: 2.67e+03 : 100%|██| 50/50 [00:45<00:00,  1.10it/s]

# %%
plt.plot(result['train_loss'])
plt.plot(result['test_loss'])
plt.legend(['train', 'test'])
plt.ylabel('RMSE')
plt.xlabel('step')
#plt.yscale('log')
# Out:
# Text(0.5, 0, 'step')

# %%
model = KAN(width=[INPUT_SHAPE, 15, 1], grid=10, k=K, seed=0)

result = model.train(dataset, opt="LBFGS", steps=10)
# Out:
# train loss: 5.02e-01 | test loss: 3.23e+00 | reg: 3.47e+01 : 100%|██| 10/10 [02:17<00:00, 13.73s/it]

# %%
plt.plot(result['train_loss'])
plt.plot(result['test_loss'])
plt.legend(['train', 'test'])
plt.ylabel('RMSE')
plt.xlabel('step')
#plt.yscale('log')
# Out:
# Text(0.5, 0, 'step')

# %% [markdown]
# ### Gradially increasing grid

# %%
width = [INPUT_SHAPE, 15, 1]
grids = np.array([3, 5, 8, 12])

train_losses = []
test_losses = []
steps = 10

for i in range(grids.shape[0]):
    if i == 0:
        model = KAN(width=width, grid=grids[i], k=K)
    if i != 0:
        model = KAN(width=width, grid=grids[i], k=K).initialize_from_another_model(model, dataset['train_input'])
    results = model.train(dataset, opt="LBFGS", steps=steps, 
                          update_grid = True, 
                          grid_update_num=6,
                          stop_grid_update_step=6)
    train_losses += results['train_loss']
    test_losses += results['test_loss']
# Out:
# train loss: 6.59e-01 | test loss: 3.86e+00 | reg: 3.97e+01 : 100%|██| 10/10 [01:50<00:00, 11.08s/it]
# train loss: 3.26e-01 | test loss: 4.03e+00 | reg: 4.17e+01 : 100%|██| 10/10 [02:01<00:00, 12.11s/it]
# train loss: 3.14e-01 | test loss: 9.43e+02 | reg: 4.17e+01 : 100%|██| 10/10 [02:25<00:00, 14.54s/it]
# train loss: 3.15e-01 | test loss: 2.13e+02 | reg: 4.16e+01 : 100%|██| 10/10 [03:02<00:00, 18.23s/it]

# %%
plt.plot(train_losses)
plt.plot(test_losses)
plt.legend(['train', 'test'])
plt.ylabel('RMSE')
plt.xlabel('step')
plt.yscale('log')

# %% [markdown]
# ## Grid=10 | hidden neurons = 10

# %%
model = KAN(width=[INPUT_SHAPE, 10, 1], grid=10, k=K, seed=0)

result = model.train(dataset, opt="LBFGS", steps=10)
# Out:
# train loss: 1.36e-01 | test loss: 2.03e+00 | reg: 3.10e+01 : 100%|██| 10/10 [01:21<00:00,  8.18s/it]

# %%
plt.plot(result['train_loss'])
plt.plot(result['test_loss'])
plt.legend(['train', 'test'])
plt.ylabel('RMSE')
plt.xlabel('step')
#plt.yscale('log')
# Out:
# Text(0.5, 0, 'step')
